# %%
#Import library yang dibutuhkan untuk proses pre-processing
import pandas as pd
import numpy as np
import string #library untuk bekerja dengan text
import re #import modul regular expression # regex untuk membersihkan kata kata tweet

# %%
#Import data CSV yang ingin diproses dalam tahapan pre-processing
header_list = ["text"]
data = pd.read_csv('D:/data2023/data3.csv', names=header_list)
data
# Out:
#                                                   text
# 0    Kenaikan harga dan kelangkaan minyak goreng te...
# 1    Minyak goreng curah subsidi dari pemerintah be...
# 2    tidak perlu larang ekspor cpo daya bulog toko ...
# 3       Minyak goreng Tidak Ada di Pasar Ciampea Bogor
# 4    Anggota Komisi VII DPR RI Mulyanto minta pemer...
# ..                                                 ...
# 995  Kenaikan harga dan kelangkaan minyak goreng di...
# 996  minyak goreng naik terus tapi harga sawit menurun
# 997  Warga barang sekarang jadi sering beli warteg ...
# 998  Pemerintah negara akan mulai mengembangkan pro...
# 999  Warga sekarang jadi sering beli warteg karena ...
#
# [1000 rows x 1 columns]

# %%
"""
Bagian ini merupakan daftar kata dari tahapan SlangWord yang digunakan sebagai Normalisasi Bahasa dimana berisi kamus slang 
secara manual yang terdiri dari 1511 kata untuk konversi kata slang ke dalam bentuk kosakata standar KBBI agar memperbaiki 
penulisan kata yang salah, mengubah singkatan, mengubah bahasa gaul yang umum digunakan menjadi kata baku.
"""

appos = {
  "thankyou":"terimakasih",
  "dikasi":"beri",
  "tau": "tahu",
  "gabisa": "tidak bisa",
  "gaada": "tidak ada",
  "lg":"lagi",
  "gada": "tidak ada",
  "pake": "pakai",
  "bnr": "benar",
  "klo": "kalau",
  "dmn": "dimana",
  "dapet": "dapat",
  "nanya": "tanya",
  "dipake": "pakai",
  "emang": "memang",
  "okay": "ya",
  "thx": "terimakasih",
  "tq": "terimakasih",
  "sngt": "sangat",
  "sgt": "sangat",
  "bgtttt":"sangat",
  "bngt": "sangat",
  "bgtt": "sangat",
  "jln": "jalan",
  "naek": "naik",
  "tokped": "tokopedia",
  "belom": "belum",
  "kemaren": "kemarin",
  "liat":"lihat",
  "topup": "top up",
  "account": "akun",
  "mantul":"mantap",
  "discount":"diskon",
  "sdh": "sudah",
  "duit":"uang",
  "karna": "karena",
  "wagelaseh": "mantap",
  "pesen": "pesan",
  "rebu":"ribu",
  "simple":"simpel",
  "best":"bagus",
  "lope": "suka",
  "lgi": "lagi",
  "krna":"karena",
  "drpd":"daripada",
  "hepi":"senang",
  "thanks":"terimakasih",
  "buy": "beli",
  "disc": "diskon",
  "shopping":"belanja",
  "milih": "pilih",
  "trs": "terus",
  "bnyak": "banyak",
  "untung pake": "untung pakai",
  "sudh":"sudah",
  "udh": "sudah",
  "nikmatin": "nikmat",
  "temanteman": "teman teman",
  "back": "kembali",
  "perjalan":"perjalanan",
  "cashkembali": "cash kembali",
  "gampah":"mudah",
  "sampe": "sampai",
  "temen": "teman",
  "pakaik": "pakai",
  "pke": "pakai",
  "mantab": "mantap",
  "ngtidak": "tidak",
  "enggak": "tidak",
  "trus":"terus",
  "jalanjalan":"jalan jalan",
  "jdi": "jadi",
  "jd": "jadi",
  "cashkembalinya":"cash kembali",
  "anter": "antar",
  "gaperlu": "tidak perlu",
  "emak":"ibu",
  "cepet": "cepat",
  "kmn": "kemana",
  "gabawa": "tidak bawa",
  "gausah": "tidak perlu",
  "byr": "bayar",
  "lagii": "lagi",
  "dehh":"deh",
  "bnyk":"banyak",
  "ntidak":"tidak",
  "smemangat": "semangat",
  "thank": "terimakasih",
  "deket": "dekat",
  "engga": "tidak",
  "menikmat":"menikmati",
  "mw":"mau",
  "bangettt":"sangat",
  "smpe":"sampai",
  "ojol":"ojek online",
  "terkejoed": "terkejut",
  "kmana": "kemana",
  "thx": "terimakasih",
  "ajaa":"saja",
  "cuss":"pergi",
  "mempersudah": "mudah",
  "bnget": "sangat",
  "hematt": "hemat",
  "hemattt": "hemat",
  "beliin":"beli",
  "smenjak": "semenjak",
  "bangett": "sangat",
  "terusss": "terus",
  "maap":"maaf",
  "irittt": "irit",
  "mantep":"mantap",
  "ajah":"saja",
  "ampe":"sampai",
  "murahhh": "murah",
  "mayan": "lumayan",
  "lbih":"lebih",
  "hrs": "harus",
  "gilaaa": "gila",
  "bangeet": "sangat",
  "maen": "main",
  "skrng": "sekarang",
  "ortu":"orang tua",
  "gmn": "bagaimana",
  "klau":"kalau",
  "gilak": "gila",
  "semanjak":"semenjak",
  "lagisg": "lagi",
  "horang":"orang",
  "bangetttt": "sangat",
  "dateng":"datang",
  "bwt": "buat",
  "macem": "macam",
  "brooo": "bro",
  "nyangka": "sangka",
  "restahurant": "restoran",
  "bingits": "sangat",
  "bisaaaaaaa":"bisa",
  "murce": "murah",
  "pkek":"pakai",
  "cmn": "cuma",
  "kmna":"kemana",
  "kyk": "seperti",
  "untungpakai": "untung pakai",
  "gegara": "karena",
  "slalu": "selalu",
  "pinter":"pintar",
  "garibet": "tidak ribet",
  "makai": "pakai",
  "mesan": "pesan",
  "mevvah":"mewah",
  "ilang":"hilang",
  "mna": "mana",
  "iritt":"irit",
  "guyss":"guys",
  "murmer":"murah",
  "mantabl":"mantap",
  "gapernah":"tidak pernah",
  "kenyaaang":"kenyang",
  "maksi": "makan siang",
  "anakanak":"anak anak",
  "bgd":"sangat",
  "nggk":"tidak",
  "lage":"lagi",
  "ksana":"kesana",
  "muraaaah":"murah",
  "trimakasih":"terimakasih",
  "dooong":"dong",
  "hemaaat":"hemat",
  "jadii":"jadi",
  "demen": "suka",
  "bkin":"buat",
  "ttp":"tetap",
  "laen":"lain",
  "markotop":"sangat",
  "hemaaaaat":"hemat",
  "jugaa": "juga",
  "iritttt":"irit",
  "bgtt":"sangat",
  "banget":"sangat",
  "bangeeet":"sangat",
  "skolah":"sekolah",
  "ngirim":"kirim",
  "bosen": "bosan",
  "iyaa":"iya",
  "caskembali":"cash kembali",
  "kawatir": "khawatir",
  "wahh":"wah",
  "hbs":"habis",
  "abisabis":"habis",
  "makanmakan":"makan makan",
  "melulu":"selalu",
  "apalagii":"apalagi",
  "bangettttt":"sangat",
  "lhooo":"lho",
  "guysburuan":"guys buruan",
  "sekarg":"sekarang",
  "dlu": "dulu",
  "rmh": "rumah",
  "ksini": "kesini",
  "sekalehhhhh": "sekali",
  "mantabh": "mantap",
  "hematmau":"hemat mau",
  "blnja":"belanja",
  "semnjak":"semenjak",
  "brani":"berani",
  "pasan":"pesan",
  "mantabll":"mantap",
  "pulak":"pula",
  "banged":"sangat",
  "muraaah":"murah",
  "dipermsudah":"mudah",
  "grgr":"gara gara",
  "gapunya":"tidak punya",
  "benarbenar":"benar benar",
  "kluar":"keluar",
  "murahhhhh":"murah",
  "bangat":"sangat",
  "kdg":"kadang",
  "oake":"oke",
  "skarang":"sekarang",
  "ajaaa":"aja",
  "ramerame":"rame",
  "gausa":"tidak perlu",
  "gatahu":"tidak tahu",
  "dimsudahkan":"mudah",
  "katidak":"tidak",
  "perantahuan":"rantau",
  "brangkat":"berangkat",
  "knp":"kenapa",
  "trima":"terima",
  "itungitung":"hitung",
  "bingit":"sangat",
  "goodluck":"good luck",
  "khwatir": "khawatir",
  "mmg":"memang",
  "bangeeeet":"sangat",
  "guysssss":"guys",
  "irittttt":"irit",
  "diskonon":"diskon",
  "hematnyaa":"hemat",
  "muraah":"murah",
  "terimakasihh":"terimakasih",
  "seneng":"senang",
  "semejak":"semenjak",
  "antarin":"antar",
  "kuatir":"khawatir",
  "malem":"malam",
  "sangattt":"sangat",
  "siangmal":"siang",
  "rame":"ramai",
  "sangatt":"sangat",
  "food":"makan",
  "lulumayan":"lumayan",
  "gooduluck":"good luck",
  "luv":"love",
  "love":"suka",
  "ngluarin":"keluar",
  "muluu":"mulu",
  "byebye":"bye",
  "gampang":"mudah",
  "terimakasi":"terimakasih",
  "terimakasihh":"terimakasih",
  "point":"poin",
  "gak":"tidak",
  "nggak":"tidak",
  "ngak":"tidak",
  "kagak": "tidak",
  "gakk":"tidak",
  "gede":"besar",
  "bokekbtl":"bokek",
  "kekinian":"hits",
  "ngerti":"tahu",
  "rantahu": "rantau",
  "smuanya":"semua",
  "smnjak":"semenjak",
  "smakin":"semakin",
  "smg":"semoga",
  "paspesan":"cukup",
  "murahh":"murah",
  "hematt":"hemat",
  "pny":"punya",
  "pnya":"punya",
  "gilakk":"gila",
  "tidakk":"tidak",
  "anggaran":"biaya",
  "gilaa":"gila",
  "buruburu":"buru buru",
  "rbu":"ribu",
  "emol":"mall",
  "promoaa":"promo",
  "promopromo":"promo promo",
  "mol":"mall",
  "dahsyat":"mantap",
  "sya":"saya",
  "custumer":"customer",
  "tmn":"teman",
  "mantapp":"mantap",
  "doangg":"doang",
  "kaga":"tidak",
  "mantapl":"mantap",
  "ngtidak":"tidak",
  "berlipatlipat":"berlipat",
  "kocek":"dompet",
  "euyyy":"euy",
  "ngtidak":"tidak",
  "gtidakman":"tidak",
  "terimakasihu":"terimakasih",
  "kosterimakasih":"terimakasih",
  "mmemang":"memang",
  "hhilang":"hilang",
  "ibuibu":"ibu ibu",
  "bhilang":"bilang",
  "sangking":"saking",
  "dekatdengan":"dekat dengan",
  "gengsss": "guys",
  "jelong": "jalan",
  "dongg": "dong",
  "sangatss": "sangat",
  "nongki": "nongkrong",
  "gretong": "gratis",
  "kmemang": "kemang",
  "bangget": "banget",
  "senanggg": "senang",
  "pesang": "pesan",
  "seringsering": "sering sering",
  "tengkyu": "terimakasih",
  "lngsung": "langsung",
  "semangatmau": "semangat mau",
  "sangatapalagi": "sangat apalagi",
  "emng": "memang",
  "akte": "akta",
  "bp": "bapak",
  "sampe": "sampai",
  "sayarat": "syarat",
  "berlakun": "berlaku",
  "masayarakat": "masyarakat",
  "dukcapil": "dispenduk",
  "dispendukcapil": "dispenduk",
  "blanko": "blangko",
  "kawin": "nikah",
  "mksh": "makasih",
  "prihal": "perihal",
  "adminitrasi": "administrasi",
  "dispendukpenduk": "dispenduk",
  "dispendukdispenduk": "dispenduk",
  "dispendispenduk": "dispenduk",
  "sy": "saya",
  "bbrp": "beberapa",
  "utk": "untuk",
  "mhn": "mohon",
  "org": "orang",
  "olh": "oleh",
  "yg": "yang",
  "jg": "juga",
  "kpd": "kepada",
  "tgl": "tanggal",
  "bln": "bulan",
  "sm": "sama",
  "dg": "dengan",
  "sby": "surabaya",
  "bhwa": "bahwa",
  "bhw": "bahwa",
  "msh": "masih",
  "ats": "atas",
  "jl": "jalan",
  "aka1": "kartukuning",
  "kartu kuning": "kartukuning",
  "kartu tanda pencari kerja": "kartukuning",
  "kartu pencari kerja": "kartukuning",
  "nggu": "nunggu",
  "slesei": "selesai",
  "dgn": "dengan",
  "bgtu": "begitu",
  "suket": "surat keterangan",
  "trima": "terima",
  "trm": "terima",
  "polisi tidur": "speedtrap",
  "pd": "pada",
  "kmarin": "kemarin",
  "kmrn": "kemarin",
  "gg": "gang",
  "lht": "lihat",
  "puskesamaas": "puskesmas",
  "stelah": "setelah",
  "manganga": "mangga",
  "ersayaaratan": "persyaratan",
  "sdengankan": "sedangkan",
  "airlanganga": "airlangga",
  "psyarat": "persyaratan",
  "ditunungangu": "ditunggu",
  "menunungangu": "menunggu",
  "sekal": "sekali",
  "risamaa": "risma",
  "terimaksih": "terimakasih",
  "pendafarannya": "pendaftarannya",
  "sehinganga": "sehingga",
  "bapakkb": "bapak",
  "masayarkat": "masyarakat",
  "ktpel": "ktp",
  "carany": "caranya",
  "prsetujuan": "persetujuan",
  "selanjutny": "selanjutnya",
  "infonyaaaaaaa": "infonya",
  "cpt": "cepat",
  "apalag": "apalagi",
  "tlagi": "lagi",
  "tinngi": "tinggi",
  "adlh": "adalah",
  "kksaya": "kk",
  "shilang": "hilang",
  "selsai": "selsai",
  "trdaftar": "terdaftar",
  "trnyata": "ternyata",
  "teralalu": "terlalu",
  "meingangalkan": "meninggalkan",
  "keajadiyan": "kejadian",
  "metanyakan": "menanyakan",
  "kasihadministrasi": "administrasi",
  "menungangunakan": "menggunakan",
  "lobang": "lubang",
  "berlobang": "berlubang",
  "harga": "biaya",
  "tangangapan": "tanggapan",
  "ppersyaratan": "persyaratan",
  "sayaarat": "syarat",
  "pagisurat": "surat",
  "upadaate": "update",
  "caranyaa": "caranya",
  "ktpunyaa": "ktpnya",
  "sayakenapa": "saya kenapa",
  "sayaarat": "syarat",
  "meningangal": "meninggal",
  "tegalsaridijanjikan": "tegalsari dijanjikan",
  "surabayaterus": "surabaya terus",
  "form": "formulir",
  "masayaarakat": "masyarakat",
  "working": "kerja",
  "bubutandan": "bubutan dan",
  "suwon": "terimakasih",
  "bener": "benar",
  "bagaimanaa": "bagaimana",
  "sblmny": "sebelumnya",
  "yaainfo": "ya info",
  "disdispenduk": "dispenduk",
  "sayaaratnya": "syaratnya",
  "ngurusin": "ngurus",
  "pamanya": "paman",
  "sarat": "syarat",
  "dbuatkan": "dibuatkan",
  "atidak": "tidak",
  "dengann": "dengan",
  "pebgurusan": "pengurusan",
  "srt": "surat",
  "brpa": "berapa",
  "tks": "terimakasih",
  "diknas": "dinas",
  "caranyaamohon": "caranya",
  "amana": "amanah",
  "wargaorang": "warga orang",
  "office": "kantor",
  "minini": "minim",
  "adad": "ada",
  "ditangangapi": "ditanggapi",
  "nungangu": "nunggu",
  "dtang": "datang",
  "ektpnya": "ektp",
  "padahl": "padahal",
  "pdhl": "padahal",
  "lejas": "jelas",
  "sekaliian": "sekalian",
  "informulirasinya": "informasi",
  "informulirasi": "informasi",
  "untk": "untuk",
  "ssamapai": "sampai",
  "praktak": "praktik",
  "formulirulir": "formulir",
  "kecamatankk": "kecamatan",
  "dikecamatan": "kecamatan",
  "penungguna": "pengguna",
  "sampa": "sampah",
  "indormasinya": "informasinya",
  "hri": "hari",
  "padan": "padam",
  "kk": "kartu keluarga",
  "gorong": "selokan",
  "goronggorong": "selokan",
  "ektpsaat": "ektp",
  "ewadulada": "ewadul",
  "mndapatkan": "mendapatkan",
  "siangmaaf": "siang maaf",
  "kmbali": "kembali",
  "pasl": "pasti",
  "telp": "telpon",
  "bsa": "bisa",
  "dminta": "diminta",
  "document": "dokumen",
  "laik": "lain",
  "kartukuningnya": "kartukuning",
  "terkahir": "terakhir",
  "notifkasi": "notifikasi",
  "dirw": "rw",
  "sampa": "sampah",
  "dimanaa": "dimana",
  "bantuannya": "bantuan",
  "megurus": "mengurus",
  "sampahil": "sampah",
  "tagangal": "tanggal",
  "tlpn": "telepon",
  "mksih": "makasih",
  "tny": "tanya",
  "almh": "almarhum",
  "nyakin": "yakin",
  "pangangilan": "panggilan",
  "thilang": "tilang",
  "reapon": "respon",
  "tertangangal": "tertanggal",
  "sampahhi": "sampah",
  "prosedurpersyaratan": "prosedur persyaratan",
  "ktpnya": "ktp",
  "kecamatanpetugas": "kecamatan petugas",
  "sampahhh": "sampah",
  "selanjutanyaa": "selanjutnya",
  "melegalisir": "legalisir",
  "makasie": "makasih",
  "berlakuya": "berlakunya",
  "begimana": "bagaimana",
  "debirokratisasi": "birokrasi",
  "public": "publik",
  "service": "pelayanan",
  "pelangangan": "pelanggaran",
  "syaratanyaa": "syarat",
  "assalamualainum": "assalamualaikum",
  "dicetakapakah": "dicetak apakah",
  "dtg": "datang",
  "habistd": "habis",
  "skr": "sekarang",
  "aparteman": "apartemen",
  "slmat": "selamat",
  "salinantarima": "salin",
  "tutidakan": "tiadakan",
  "direspon": "respon",
  "cepatanyaa": "cepat",
  "disepanjang": "sepanjang",
  "kenyamanahn": "kenyamanan",
  "apartment": "apartemen",
  "matimulai": "mati",
  "seoanjang": "sepanjang",
  "padamg": "padam",
  "expired": "mati",
  "expire": "mati",
  "brapa": "berapa",
  "kartukeluargas": "kartu keluarga",
  "pembuatanya": "buat",
  "pengambilanya": "ambil",
  "skali": "sekali",
  "sekarangk": "sekarang",
  "perosedurnya": "prosedur",
  "tetapai": "tetapi",
  "pernyaataan": "pernyataan",
  "ank": "anak",
  "tlng": "tolong",
  "bbagaimana": "bagaimana",
  "selanjutnyaa": "selanjutnya",
  "dftrkan": "daftarkan",
  "dokterbidan": "dokter bidan",
  "disurabaya": "surabaya",
  "pertanyannya": "pertanyaannya",
  "shg": "sehingga",
  "lagis": "lagi",
  "ngangih": "nagih",
  "sunungguh": "sungguh",
  "selsai": "selesai",
  "selesa": "selesai",
  "sampahsampah": "sampah",
  "sampahl": "sampah",
  "sampa": "sampah",
  "sekarangg": "sekarang",
  "diiklanakan": "iklan",
  "pavingisasi": "paving",
  "sesunguhnya": "sesungguhnya",
  "msampaht": "sampah",
  "plihan": "pilihan",
  "slh": "salah",
  "stu": "satu",
  "light": "lampu",
  "pavingnya": "paving",
  "padam": "mati",
  "padaam": "mati",
  "selokananselokan": "selokan",
  "tangap": "tanggap",
  "selokananselokanselokanuntuk": "selokan",
  "agr": "agar",
  "jngn": "jangan",
  "spy": "supaya",
  "bleh": "boleh",
  "samaa": "sama",
  "memasukartukeluargaan": "kartukeluarga",
  "lengkapinsampahh": "sampah",
  "sampahh": "sampah",
  "sampa": "sampah",
  "ngurusnya": "urus",
  "bantuanya": "bantuan",
  "ditandatangani": "tanda tangan",
  "samap": "sama",
  "sdengan": "dengan",
  "sulitanyaa": "sulit",
  "disetujui": "setuju",
  "kelurahannya": "kelurahan",
  "sekal": "sekali",
  "temanaku": "temanku",
  "keluarahan": "kelurahan",
  "sekaliigus": "sekaligus",
  "nomernya": "nomer",
  "kekelurahan": "kelurahan",
  "kartukeluargaini": "kartu keluarga",
  "siolacapek": "siola",
  "baharu": "baru",
  "kartukuninga": "kartukuning",
  "prngamblan": "pengambilan",
  "tingangalnya": "tanggalnya",
  "teimakasih": "terimakasih",
  "melelui": "melalui",
  "samaua": "sama",
  "persayaratannya": "syarat",
  "kelurahaan": "kelurahan",
  "dikecamtan": "kecamatan",
  "kmrin": "kemarin",
  "kntor": "kantor",
  "hrus": "harus",
  "kecamtan": "kecamatan",
  "dikecamtan": "kecamatan",
  "penpanjangnya": "perpanjangan",
  "komputereh": "komputer",
  "selesa": "selesai",
  "samak": "sama",
  "harapanan": "harapan",
  "ragajika": "raga",
  "ragasebenarnya": "raga",
  "ragawan": "raga",
  "pnerangan": "penerangan",
  "tmpat": "tempat",
  "sblm": "sebelum",
  "teribuka": "terbuka",
  "tirtoasr": "tirtoasri",
  "trlalu": "terlalu",
  "membahaykan": "membahayakan",
  "terrealisasi": "terealisasi",
  "gelapcoba": "gelap",
  "nnti": "nanti",
  "sngat": "sangat",
  "mengfasilitasi": "memfasilitasi",
  "mnghindari": "menghindari",
  "ditraffic": "traffic",
  "jpu": "pju",
  "terimaadministrasi": "terima administrasi",
  "yaadministrasi": "ya administrasi",
  "surabayaadministrasi": "surabaya administrasi",
  "alay":"aneh",
  "ancur":"hancur",
  "asal mangap":"ceroboh",
  "asbun":"cerewet",
  "asik":"asyik",
  "bacot":"bawel",
  "bae":"baik",
  "baek":"baik",
  "basbang":"basi",
  "bcus":"becus",
  "belagu":"songong",
  "bete":"kesal",
  "bgus":"bagus",
  "bls":"balas",
  "bner":"benar",
  "bnr":"benar",
  "bntrok":"bentrok",
  "bodo":"masa bodoh",
  "boong":"bohong",
  "brni":"berani",
  "buset":"buset",
  "cakep":"bagus",
  "cetek":"mudah",
  "cingcong":"omong",
  "cocot":"omong",
  "cuek":"cuek",
  "demen":"suka",
  "dkung":"dukung",
  "ego":"bodoh",
  "egp":"masa bodoh",
  "gaje":"tidak jelas",
  "gazebo":"tidak jelas",
  "geblek":"bodoh",
  "geje":"tidak jelas",
  "gercep":"cepat",
  "getol":"rajin",
  "gile":"gila",
  "goblog":"bodoh",
  "gombal":"bohong",
  "guoblok":"bodoh",
  "jls":"jelas",
  "kabur":"kabur",
  "kcwa":"kecewa",
  "kcewa":"kecewa",
  "kece":"bagus",
  "kere":"miskin",
  "kesel":"kesal",
  "kismin":"miskin",
  "kongkalikong":"sekongkol",
  "koplak":"bodoh",
  "lamreta":"lambat",
  "lebay":"norak",
  "mabok":"mabuk",
  "makjul":"makzul",
  "males":"malas",
  "mantab":"mantap",
  "maruk":"rakus",
  "memble":"jelek",
  "mencla mencle":"lelet",
  "mending":"baik",
  "mjd":"menjadi",
  "nampol":"tampar",
  "ngabur":"ngacir",
  "ngaco":"sembarang",
  "ngamuk":"marah",
  "ngawur":"sembarang",
  "ngeles":"berkilah",
  "ngeri":"takut",
  "ngeyel":"keras kepala",
  "ngotot":"memaksa",
  "oon":"bodoh",
  "parno":"takut",
  "php":"pemberi harapan palsu",
  "rempong":"rumit",
  "rese":"sebal",
  "resek":"sebal",
  "ribet":"rumit",
  "sarap":"gila",
  "sebel":"sebal",
  "semprul":"bodoh",
  "slah":"salah",
  "slamat":"selamat",
  "sok":"sombong",
  "somplak":"bodoh",
  "stress":"gila",
  "taik'":"kotoran",
  "tajir":"kaya",
  "thks":"terima kasih",
  "thx":"terima kasih",
  "tkut":"takut",
  "tkt":"takut",
  "tolol":"bodoh",
  "top":"bagus",
  "yg":"yang",
  "jgn":"jangan",
  "bnyk":"banyak",
  "byk":"banyak",
  "org":"orang",
  "kagak":"tidak",
  "gak":"tidak",
  "gk":"tidak",
  "ga":"tidak",
  "nggak":"tidak",
  "kaga":"tidak",
  "emang":"memang",
  "emg":"memang",
  "emng":"memang",
  "klo":"kalau",
  "kalo":"kalau",
  "klu":"kalau",
  "kl":"kalau",
  "dr":"dari",
  "brni":"berani",
  "gada":"tidak ada",
  "mslh":"masalah",
  "bnjir":"banjir",
  "mcet":"macet",
  "lg":"lagi",
  "smoga":"semoga",
  "smga":"semoga",
  "dgn":"dengan",
  "dg":"dengan",
  "bs":"bisa",
  "mju":"maju",
  "sblum":"sebelum",
  "tk":"tidak",
  "tdk":"tidak",
  "jd":"jadi",
  "sy":"saya",
  "gue":"saya",
  "gw":"saya",
  "gu":"saya",
  "gua":"saya",
  "wa":"saya",
  "utk":"untuk",
  "untk":"untuk",
  "u":"untuk",
  "ut":"untuk",
  "unt":"untuk",
  "sdh":"sudah",
  "sdah":"sudah",
  "udah":"sudah",
  "uda":"sudah",
  "membuktikn":"membuktikan",
  "mnyalahkan":"menyalahkan",
  "masyarkt":"masyarakat",
  "mnjadi":"menjadi",
  "karna":"karena",
  "krn":"karena",
  "bakal":"akan",
  "medsos":"media sosial",
  "mrk":"mereka",
  "pd":"pada",
  "sj":"saja",
  "aja":"saja",
  "adl":"adalah",
  "adlh":"adalah",
  "adlah":"adalah",
  "ahock":"ahok",
  "jt":"juta",
  "xuma":"cuma",
  "cma":"cuma",
  "sbg":"sebagai",
  "itung":"hitung",
  "omong":"bicara",
  "ngomong":"bicara",
  "bikin":"buat",
  "d":"di",
  "spt":"seperti",
  "sprti":"seperti",
  "jg":"juga",
  "dtg":"datang",
  "pengen":"pengin",
  "usah":"perlu",
  "ttp":"tetap",
  "nmr":"nomor",
  "dlm":"dalam",
  "thn":"tahun",
  "th":"tahun",
  "dpn":"depan",
  "dn":"dan",
  "n":"dan",
  "mk":"maka",
  "mrpkn":"merupakan",
  "Bngs":"bangsa",
  "dsb":"dan sebagainya",
  "memiminpin":"memimpin",
  "jkt":"jakarta",
  "lu":"anda",
  "lo":"anda",
  "luh":"anda",
  "msh":"masih",
  "lbh":"lebih",
  "lbih":"lebih",
  "thd":"terhadap",
  "thdp":"terhadap",
  "yim":"yusril",
  "slalu":"selalu",
  "sllu":"selalu",
  "mmnta":"meminta",
  "bpk":"bapak",
  "p":"pak",
  "tp":"tapi",
  "liat":"lihat",
  "bkn":"bukan",
  "bkan":"bukan",
  "wkt":"waktu",
  "wktu":"waktu",
  "suwer":"sumpah",
  "diubah":"dirubah",
  "gentelement":"gentlement",
  "kpd":"kepada",
  "jjur":"jujur",
  "jjr":"jujur",
  "stlh":"setelah",
  "tlh":"telah",
  "rbt":"ribut",
  "pr":"para",
  "seneng":"senang",
  "kt":"kita",
  "hrs":"harus",
  "smpe":"sampai",
  "sampe":"sampai",
  "ampe":"sampai",
  "Sblm":"sebelum",
  "blum":"belum",
  "belom":"belum",
  "blom":"belum",
  "blm":"belum",
  "temen":"teman",
  "tmn":"teman",
  "temn":"teman",
  "tmen":"teman",
  "tman":"teman",
  "skrng":"sekarang",
  "skrg":"sekarang",
  "skg":"sekarang",
  "byaran":"bayaran",
  "duit":"uang",
  "dpt":"dapat",
  "smua":"semua",
  "smwa":"semua",
  "smw":"semua",
  "tuh":"itu",
  "ntu":"itu",
  "tgs":"tugas",
  "knp":"kenapa",
  "knapa":"kenapa",
  "knpa":"kenapa",
  "np":"kenapa",
  "deket":"dekat",
  "wargan":"warga",
  "wrg":"warga",
  "wrga":"warga",
  "sm":"sama",
  "sma":"sama",
  "tntg":"tentang",
  "pake":"pakai",
  "mo":"mau",
  "krja":"kerja",
  "krj":"kerja",
  "mmg":"memang",
  "blkg":"belakang",
  "parte":"partai",
  "bales":"balas",
  "bls":"balas",
  "bles":"balas",
  "muke":"muka",
  "Gub":"gubernur",
  "ktemu":"bertemu",
  "klelep":"tenggelam",
  "aje":"saja",
  "bise":"bisa",
  "selame":"selama",
  "gara":"karena",
  "drpd":"daripada",
  "gebuk":"hajar",
  "mgkin":"mungkin",
  "gares":"garis",
  "beres":"rapi",
  "plis":"tolong",
  "tlng":"tolong",
  "tlong":"tolong",
  "ujan":"hujan",
  "hjn":"hujan",
  "masy":"masyarakat",
  "nd":"dan",
  "udh":"sudah",
  "cepet":"cepat",
  "cpt":"cepat",
  "cpat":"cepat",
  "cpet":"cepat",
  "rame":"ramai",
  "dmn":"di mana",
  "taruan":"taruhan",
  "nih":"ini",
  "bener":"benar",
  "benelan":"benaran",
  "mahluk":"makhluk",
  "mabok":"mabuk",
  "ttg":"tentang",
  "tj":"transjakarta",
  "kelmpk":"kelompok",
  "klmpk":"kelompok",
  "mlh":"malah",
  "blg":"bilang",
  "lucuk":"lucu",
  "kyk":"seperti",
  "kayak":"seperti",
  "keq":"dong",
  "ente":"anda",
  "ok":"oke",
  "gpp":"tidak apa apa",
  "laen":"lain",
  "macem":"macam",
  "mcem":"macam",
  "mcam":"macam",
  "pny":"punya",
  "pnya":"punya",
  "dkngan":"dukungan",
  "jngn":"jangan",
  "drpada":"daripada",
  "sombg":"sombong",
  "walo":"walau",
  "srmangat":"semangat",
  "dah":"sudah",
  "meyelesaikan":"menyelesaikan",
  "bhw":"bahwa",
  "bhwa":"bahwa",
  "pmimpin":"pemimpin",
  "ye":"ya",
  "abis":"habis",
  "bw":"bawa",
  "bwa":"bawa",
  "ngak":"tidak",
  "aering":"sering",
  "srng":"sering",
  "sring":"sering",
  "jkw":"jokowi",
  "joko":"jokowi",
  "skr":"sekarang",
  "rs":"rumah sakit",
  "sw":"sumber waras",
  "nasip":"nasib",
  "ad":"ada",
  "doang":"saja",
  "manteman":"teman teman",
  "mara":"marah",
  "koq":"kok",
  "menyatkan":"menyatakan",
  "dll":"dan lain lain",
  "bgt":"sangat",
  "ngasi":"kasih",
  "ktipu":"ketipu",
  "klw":"kalau",
  "mngmbil":"mengambil",
  "jlur":"jalur",
  "brarti":"berarti",
  "mnghormati":"menghormati",
  "pgn":"pengin",
  "prnh":"pernah",
  "prnah":"pernah",
  "pernh":"pernah",
  "denger":"dengar",
  "yth":"yang terhormat",
  "kbiasaan":"kebiasaan",
  "mkn":"makan",
  "rkyt":"rakyat",
  "brani":"berani",
  "mmberantas":"memberantas",
  "maap":"maaf",
  "kemaren":"kemarin",
  "kmrn":"kemarin",
  "kmaren":"kemarin",
  "kmren":"kemarin",
  "pede":"percaya diri",
  "grombolan":"sekumpulan",
  "slah":"salah",
  "slh":"salah",
  "salh":"salah",
  "alsan":"alasan",
  "alsn":"alasan",
  "alasn":"alasan",
  "sya":"saya",
  "sdangkan":"sedangkan",
  "it":"itu",
  "pingin":"pengin",
  "g":"tidak",
  "sory":"maaf",
  "taon":"tahun",
  "tu":"itu",
  "asbun":"asal bunyi",
  "elo":"anda",
  "ap":"apa",
  "km":"anda",
  "ngamuk":"marah",
  "mgkn":"mungkin",
  "tsb":"tersebut",
  "bbrp":"beberapa",
  "jkrt":"jakarta",
  "klean":"kalian",
  "sbnrnya":"sebenarnya",
  "mrasa":"merasa",
  "kcil":"kecil",
  "kcl":"kecil",
  "sgt":"sangat",
  "trbntu":"terbantu",
  "kppmpinan":"kepemimpinan",
  "gg":"tidak",
  "ntk":"untuk",
  "kog":"kok",
  "kalopun":"kalaupun",
  "macarakat":"masyarakat",
  "nyogok":"suap",
  "cth":"contoh",
  "cnth":"contoh",
  "pdhl":"padahal",
  "spy":"supaya",
  "agr":"agar",
  "trjd":"terjadi",
  "ane":"saya",
  "ribed":"susah",
  "tertanyata":"ternyata",
  "dng":"dengan",
  "dl":"dulu",
  "mn":"mana",
  "tah":"entah",
  "dukun":"dukung",
  "donk":"dong",
  "tuk":"untuk",
  "bosen":"bosan",
  "smg":"semoga",
  "hdp":"hidup",
  "ngliat":"melihat",
  "gologan":"golongan",
  "jaksel":"jakarta selatan",
  "kp":"kampung",
  "korop":"korupsi",
  "kmarin":"kemarin",
  "ama":"sama",
  "uploud":"upload",
  "enggak":"tidak",
  "pinter":"pintar",
  "mgatakan":"mengatakan",
  "wlpun":"walaupun",
  "hnya":"hanya",
  "hny":"hanya",
  "caper":"cari perhatian",
  "bolot":"tuli",
  "ngarep":"harap",
  "alesan":"alasan",
  "menaikan":"menaikkan",
  "egak":"tidak",
  "pencoblisan":"pencoblosan",
  "gegara":"karena",
  "sebenernya":"sebenarnya",
  "ketum":"ketua umum",
  "mrpk":"merupakan",
  "ngejadi":"menjadi",
  "ngenentukan":"menentukan",
  "ntar":"nanti",
  "ame":"sama",
  "dach":"saja",
  "sdg":"sedang",
  "ngotot":"kekeh",
  "boring":"bosan",
  "pmmpin":"pemimpin",
  "amat":"sangat",
  "jugak":"juga",
  "keknya":"sepertinya",
  "ngeruk":"dapat",
  "modus":"modal dusta",
  "koar":"teriak",
  "nyinyir":"nyindir",
  "ujng":"ujung",
  "skrang":"sekarang",
  "ky":"seperti",
  "keruwetan":"kerumitan",
  "die":"dia",
  "ahoak":"ahok",
  "belon":"belum",
  "melaui":"melalui",
  "nebeng":"bersama",
  "ngakak":"tertawa",
  "deramah":"drama",
  "dgr":"dengar",
  "ko":"kok",
  "kujungi":"kunjungi",
  "tenar":"terkenal",
  "lewat":"melalui",
  "lwt":"melalui",
  "udeh":"sudah",
  "jdi":"jadi",
  "mangkanya":"oleh sebab itu",
  "php":"pemberi harapan palsu",
  "kelewatan":"keterlaluan",
  "legowo":"sabar",
  "terslubung":"tersembunyi",
  "dst":"dan seterusnya",
  "pili":"pilih",
  "pres":"presiden",
  "karu":"kira",
  "progress":"kemajuan",
  "nomer":"nomor",
  "bleh":"boleh",
  "ahox":"ahok",
  "ato":"atau",
  "trbukti":"terbukti",
  "tkg":"tukang",
  "suadah":"sudah",
  "mkin":"semakin",
  "jargon":"sebutan",
  "olh":"oleh",
  "transj":"transjakarta",
  "lgs":"langsung",
  "begini":"seperti ini",
  "tsbt":"tersebut",
  "jakarte":"jakarta",
  "atw":"atau",
  "mraih":"meraih",
  "bego":"bodoh",
  "ndak":"tidak",
  "bca":"baca",
  "gamau":"tidak mau",
  "temlen":"linimasa",
  "mensyen":"mention",
  "gbrnr":"gubernur",
  "artix":"artinya",
  "pkrx":"pikirnya",
  "yaudah":"ya sudah",
  "rese":"ganggu",
  "kasi":"kasih",
  "pst":"pasti",
  "ambrol":"hancur",
  "kabeh":"saja",
  "mang":"memang",
  "embat":"ambil",
  "goblok":"bodoh",
  "cr":"cari",
  "cri":"cari",
  "haters":"pembenci",
  "hater":"pembenci",
  "cuman":"cuma",
  "msi":"masih",
  "shg":"sehingga",
  "bhkn":"bahkan",
  "banget":"sangat",
  "br":"baru",
  "kapok":"capai",
  "bwt":"untuk",
  "bngt":"sangat",
  "pedeipeh":"pdip",
  "trus":"terus",
  "ind":"indonesia",
  "mao":"mau",
  "becus":"bisa",
  "aj":"saja",
  "sekedar":"sekadar",
  "muak":"tidak suka",
  "ma":"sama",
  "uangny":"uangnya",
  "maruk":"rakus",
  "smntr":"sementara",
  "lma":"lama",
  "nglunjak":"makin menjadi",
  "iye":"iya",
  "de el el":"dan lain lain",
  "terakhr":"terakhir",
  "mangap":"terbuka",
  "ketimbang":"daripada",
  "pnh":"pernah",
  "kudet":"kurang update",
  "kbusukan":"kebusukan",
  "psti":"pasti",
  "suporter":"pendukung",
  "ati":"hati",
  "oprasi":"operasi",
  "yeh":"ya",
  "pulak":"pula",
  "bajer":"buzzer",
  "lpngn":"lapangan",
  "pmpn":"pemimpin",
  "dy":"dia",
  "ky":"seperti",
  "sosmed":"media sosial",
  "mnjatuhkan":"menjatuhkan",
  "hebring":"sulit",
  "jakrta":"jakarta",
  "aprtmen":"apartemen",
  "cmn":"cuma",
  "sjk":"sejak",
  "ngak":"tidak",
  "ngana":"anda",
  "tros":"terus",
  "gaseru":"tidak seru",
  "slama":"selama",
  "shingga":"sehingga",
  "masak":"masa",
  "jln":"jalan",
  "tj":"transjakarta",
  "caya":"percaya",
  "palagi":"apalagi",
  "akh":"ah",
  "bisax":"bisanya",
  "bgmn":"bagaimana",
  "neh":"ini",
  "bertobat":"bertaubat",
  "sbrani":"seberani",
  "klwpn":"kalaupun",
  "ngebantuin":"membantu",
  "mank":"memang",
  "sblumnya":"sebelumnya",
  "ngimpi":"mimpi",
  "semaleman":"semalaman",
  "kamp":"kampung",
  "lsg":"langsung",
  "ajah":"saja",
  "kmn":"ke mana",
  "pbawa":"pembawa",
  "buzer":"buzzer",
  "ogah":"malas",
  "ngehek":"bangsat",
  "aq":"saya",
  "tbiasa":"terbiasa",
  "gt":"begitu",
  "hecker":"retas",
  "sgala":"segala",
  "jng":"jangan",
  "elu":"anda",
  "trutama":"terutama",
  "bazer":"buzzer",
  "hoax":"palsu",
  "gsur":"gusur",
  "enteng":"mudah",
  "bingits":"sangat",
  "skaligus":"sekaligus",
  "pantesan":"pantasan",
  "napi":"nara pidana",
  "temn":"teman",
  "dm":"demokrat",
  "tlah":"telah",
  "sk":"suka",
  "wong":"orang",
  "unfol":"unfollow",
  "unfoll":"unfollow",
  "sbgai":"sebagai",
  "mba":"mbak",
  "gaperlu":"tidak perlu",
  "dikasi":"diberi",
  "netijen":"netizen",
  "sngt":"sangat",
  "mamam":"makan",
  "bernubuat":"berbuat",
  "spert":"seperti",
  "situ":"anda",
  "dkt":"dekat",
  "smua":"semua",
  "disogok":"disuap",
  "yach":"ya",
  "pk":"pakai",
  "smpaikan":"sampaikan",
  "papa":"apa apa",
  "trs":"terus",
  "doong":"dong",
  "jk":"jika",
  "feb":"februari",
  "ntn":"nonton",
  "pkl":"pukul",
  "bsok":"besok",
  "mw":"mau",
  "msih":"masih",
  "skt":"sekitar",
  "y":"ya",
  "yaelaa":"ya sudah lah",
  "seromony":"upacara",
  "sluruh":"seluruh",
  "maapan":"maafan",
  "bg":"bagi",
  "sdr":"saudara",
  "imbauan":"himbauan",
  "nnti":"nanti",
  "cm":"cuma",
  "ptgs":"petugas",
  "jakbar":"jakarta barat",
  "tnya":"tanya",
  "saluut":"salut",
  "lgi":"lagi",
  "sampaiken":"sampaikan",
  "gub":"gubernur",
  "akherat":"akhirat",
  "pdi pak":"pdip",
  "perhtungan":"perhitungan",
  "sumbersumb":"sumber sumber",
  "ojolpsbbpembantaian":"ojol psbb pembantaian",
  "optimi":"optimis",
  "suks": "sukses",
  "seriu": "serius",
  "aparatpetuga": "aparat petugas",
  "lamalama":"lama lama",
  "kbayang": "kebayang",
  "viru": "virus",
  "stiap":"setiap",
  "rili":"rilis",
  "statu":"status",
  "sanalempar":"sana lempar",
  "menolong yuk":"menolong yuk",
  "dengam":"dengan",
  "i":"",
  "keadilanyg":"keadilan yang",
  "ygbenar":"yang benar",
  "gx":"tidak",
  "coronamati":"corona mati",
  "kamb":"kambing",
  "sdng":"sedang",
  "teriakteriak":"teriak teriak",
  "orangorang":"orang orang",
  "sendirisendiri":"sendiri",
  "kluar":"keluar",
  "setop":"stop",
  "penguasaha":"pengusaha",
  "jugaaa":"juga",
  "pembagiansembakobikinberabe":"pembagian sembako bikin berabe",
  "berabe":"berantakan",
  "congooornya":"omongan",
  "pade":"pada",
  "gedeee":"besar",
  "yv":"yg",
  "yee":"ya",
  "povokativ":"provokatif",
  "kyny":"sepertinya",
  "sll":"selalu",
  "kreta":"kereta",
  "mlm":"malam",
  "gdg":"gedung",
  "guernur":"gubernur",
  "sebenernya":"sebenarnya",
  "smp":"sampe",
  "kpn":"kapan",
  "psr":"pasar",
  "bgni":"begini",
  "x":"kali",
  "gin":"gini",
  "nmnya":"namanya",
  "kn":"kan",
  "didtgi":"didatangi",
  "yuk":"ayo",
  "pk":"pak",
  "nya":"",
  "telat":"terlambat",
  "bejubel":"sembarangan",
  "brgkt":"berangkat",
  "monmap":"mohon maaf",
  "btasi":"batasi",
  "mslhnya":"masalahnya",
  "hr":"hari",
  "gmna":"gimana",
  "djkrta":"di jakarta",
  "satnya":"saatnya",
  "optimispresidenkita":"optimis presiden kita",
  "ojolpsbpembantaian":"ojol psb pembantaian",
  "bbrp":"beberapa",
  "brp":"berapa",
  "bole":"boleh",
  "jan":"jangan",
  "plng":"pulang",
  "ditungu":"ditunggu",
  "tlg":"tolong",
  "ape":"apa",
  "grkn":"gerakan",
  "nmun":"namun",
  "diberlakukanya":"diberlakukannya",
  "mlam":"malam",
  "bole":"boleh",
  "apdet":"update",
  "tetjamin":"terjamin",
  "setres":"stress",
  "ptugs":"petugas",
  "prtai":"partai",
  "bgaimna":"bagaimana",
  "mlayani":"melayani",
  "negray" :"negara",
  "bisay" : "bisa",
  "pncitran" : "pencitraan",
  "pngelola" : "pengelola",
  "smbong" : "sombong",
  "mncontoh" : "mencontoh",
  "kpda" : "kepada",
  "negra" : "negara",
  "brhasil" : "berhasil",
  "melkukn" : "melakukan",
  "memnusiakn" : "memanusiakan",
  "tx":"makasih",
  "bt":"bete",
  "kg":"tidak",
  "rkyat" : "rakyat",
  "psb":"psbb",
  "tati":"taati",
  "bandel":"nakal",
  "engga":"tidak",
  "enga":"tidak",
  "jilidi":"jilid satu",
  "mg":"semoga",
  "tpi":"tapi",
  "mal":"pusat perbelanjaan",
  "gonta":"ganti",
  "exit":"keluar",
  "dilongarin":"dilonggarin",
  "syantik":"cantik",
  "longarkan":"longgarkan",
  "tivi":"televisi",
  "kegilan":"kegilaan",
  "dahla":"sudah",
  "ksh":"kasih",
  "loe":"anda",
  "fucek":"anjing",
  "dimaksudkn" : "dimaksudkan",
  "dukunganya":"dukungannya",
  "mainset":"pola pikir",
  "memamtuhi" : "mematuhi",
  "iangkah" : "langkah",
  "implementasikanya" : "dimplementasikannya",
  "tidak_nyadar" : "tidak sadar",
  "ojo" : "jangan",
  "lembek" : "lemah",
  "dimaksudkn" : "dimaksudkan",
  "dri":"dari",
  "tmpt":"tempat",
  "bgst":"sialan",
  "dmana" : "dimana",
  "rcn":"racun",
  "siapaun" : "siapapun",
  "pemrth" : "pemerintah",
  "membrk" : "memberikan",
  "bntuan" : "bantuan",
  "drmana" : "darimana",
  "indon":"indonesia",
  "brengsek":"anjing",
  "emnk":"memang",
  "semogs":"semoga",
  "dirmh":"di rumah",
  "sangup":"sanggup",
  "sejsk" : "sejak",
  "sampe":"sampai",
  "seprti" : "seperti",
  "ush":"usah",
  "ngelarang":"melarang",
  "melangar":"melanggar",
  "ngikutin":"mengikuti",
  "nga":"tidak",
  "sblmnya":"sebelumnya",
  "gbs":"tidak bisa",
  "bngst":"sialan",
  "perintah":"pemerintah",
    "kusus":"khusus"
}

# %%
"""
Fungsi ini digunakan untuk pembersihan setiap komentar dalam tweet yang dimana berisi tahapan proses membersihkan simbol-simbol
atau karakter yang berulang dan kurang penting yang tidak diperlukan dalam dataset yang berakibat mengganggu proses klasifikasi 
dengan cara menghilangkan noise/gangguan (simbol bawaan atau tanda baca default dari twitter) agar kualitas data menjadi 
lebih baik sehingga hasil penelitian lebih akurat
"""
def clean_text(reviews):
    all_reviews = list()
    lines = reviews["text"].values.tolist()
    for text in lines:
        text = re.sub("RT "," ", text) #hapus RT 
        text = re.sub("@\\S+", " ", text) #hapus @ 
        text = re.sub(r"http\S+", " ", text) #hapus URL atau incomplete URL
        text = re.sub("#\S+", " ", text) #hapus #
        text = re.sub(r"\d+", " ", text) #hapus angka 1 digit atau lebih
        text = re.sub(r"[-!\"#$%&'()*+,./:;<=>?@\[\\\]_`{|}~ÃƒÂ¿]", " ", text) #hapus simbol sama seperti punctuation character
        text = re.sub(r"\n", " ", text) #hapus newline
        text = re.sub(" +", " ",text) #gabung spasi dengan huruf belakangnya
        text = text.translate(str.maketrans(" "," ",string.punctuation)) 
        #remove punctuation atau tanda baca, string berisi huruf, spasi, angka.
        #Dan ada tanda baca: karakter ini termasuk koma dan titik serta titik koma.
        
        text = text.strip() #hapus spasi di depan dan di belakang
        text = re.sub("\s+"," ", text) #hapus beberapa spasi menjadi satu spasi
        text = re.sub(r"\b[a-zA-Z]\b", " ", text) #hapus single character
        all_reviews.append(text) #Setelah semua komentar selesai dibersihkan, komentar atau text di dalam variabel "line" 
        #tersebut akan ditambahkan atau ditaruh ke dalam variabel all_reviews dimana data tersebut akan berupa dalam bentuk list
    return all_reviews
all_reviews = clean_text(data)
print('Cleansing Data Result : \n') 
all_reviews[0:20]


#referensi : https://docs.python.org/3/library/re.html
#referensi : https://www3.ntu.edu.sg/home/ehchua/programming/howto/Regexe.html
#referensi : https://www.dotnetperls.com/punctuation-python
# Out:
# Cleansing Data Result :
# ['Kenaikan harga dan kelangkaan minyak goreng tentu membuat masyarakat Indonesia kelimpungan',
#  'Minyak goreng curah subsidi dari pemerintah belum ada di Kota Malang pedagang dan pembeli mohon bersabar',
#  'tidak perlu larang ekspor cpo daya bulog toko jaring distribusi minyak goreng bulog produsen',
#  'Minyak goreng Tidak Ada di Pasar Ciampea Bogor',
#  'Anggota Komisi VII DPR RI Mulyanto minta pemerintah terus menjaga momentum penurunan harga minyak goreng sampai menuju HET',
#  'Minyak goreng Belum Terlihat di Tabanan',
#  'Aneh sih pas harga masih   liter nyarinya susah bgt giliran harga normal eh rak minyak goreng penuh',
#  'Asli sih minyak goreng itu penting banget udah mahal nyarinya susah lagi tanpa minyak kita gak bisa berlemak riaa',
#  'Masih WARAS kah Di mana keberpihakan Negara kpd rakyatnya Kalah oleh kartel minyak goreng',
#  'Brand baru negara kita adalah negara miskin susah minyak goreng pak ga perlu sok banyak gaya rakyat yg tau aslinya',
#  'ini gak ada yang mau demo turunin harha minyak goreng',
#  'Pemerintah emng   becus mengurus minyak goreng Cabut izin produksi sawit kelar itu mata sipit balik kampung',
#  'Selamat datang di negara lawak dimana harga minyak goreng mahal di negara penghasil minyak sawit yang cukup besar',
#  'biaya minyak goreng turun mudah mudahan turun masyarakat tenang ayo disiplin prokes yah',
#  'biaya minyak goreng turun',
#  'belum lagi daerah daerah pencil butuh minyak goreng',
#  'anggota dpr ri biaya cpo dunia merosot biaya minyak goreng indonesia',
#  'Harga Minyak Goreng di Kota Jambi Hari Ini Juli Mulai Rp Ribu Per Liter',
#  'Turun Terus Harga Minyak Goreng Jatuh Terendah Jadi Rp per liter',
#  'nilai rugi negara minyak goreng fantastis']

# %%
data=pd.DataFrame(all_reviews, columns=['text'])
data
# Out:
#                                                   text
# 0    Kenaikan harga dan kelangkaan minyak goreng te...
# 1    Minyak goreng curah subsidi dari pemerintah be...
# 2    tidak perlu larang ekspor cpo daya bulog toko ...
# 3       Minyak goreng Tidak Ada di Pasar Ciampea Bogor
# 4    Anggota Komisi VII DPR RI Mulyanto minta pemer...
# ..                                                 ...
# 995  Kenaikan harga dan kelangkaan minyak goreng di...
# 996  minyak goreng naik terus tapi harga sawit menurun
# 997  Warga barang sekarang jadi sering beli warteg ...
# 998  Pemerintah negara akan mulai mengembangkan pro...
# 999  Warga sekarang jadi sering beli warteg karena ...
#
# [1000 rows x 1 columns]

# %%
#library yang diperlukan
#!pip install Sastrawi
#!pip install nltk
#nltk.download("popular")

#Import library yang dibutuhkan dalam proses pre-processing
import string #library untuk bekerja dengan text
import re #regex library
#import itertools #Library iterator untuk perulangan yang efisien
import nltk #library yang merupakan bagian dari NLP yang untuk bekerja dengan permodelan teks
from nltk.tokenize import word_tokenize #import library package untuk proses Tokenisasi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import library package untuk proses Stemming
from nltk.corpus import stopwords #import library package untuk proses Stopwords
#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary

# %%
# ------ Case Folding --------
#Digunakan untuk transform huruf menjadi huruf lower atau kecil agar seragam
data['sentiment_text'] = data['text'].str.lower()

print('Case Folding Result : \n')
print(data['sentiment_text'].head(20))
print('\n\n\n')

#Fungsi yang digunakan untuk mengganti atau menghapus karakter yang spesial
def remove_text_special(sentiment_text):
    #hapus tab, new line, and back slice
    sentiment_text = sentiment_text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"").replace('\x80¦',"")
    #hapus non ASCII (emoticon, chinese word, dll)
    sentiment_text = sentiment_text.encode('ascii', 'replace').decode('ascii')
    return sentiment_text     

data['sentiment_text'] = data['sentiment_text'].apply(remove_text_special)

#hapus emoji ✍ 🌷 📌 👈🏻 🖥
def remove_emoji(sentiment_text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002500-\U00002BEF"  # chinese char
                           u"\U00002702-\U000027B0"
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           u"\U0001f926-\U0001f937"
                           u"\U00010000-\U0010ffff"
                           u"\u2640-\u2642"
                           u"\u2600-\u2B55"
                           u"\u200d"
                           u"\u23cf"
                           u"\u23e9"
                           u"\u231a"
                           u"\ufe0f"  # dingbats
                           u"\u3030"
                               #mengonversi data input ke Unicode
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', sentiment_text)

data['sentiment_text'] = data['sentiment_text'].apply(remove_emoji)

# ------ Tokenizing ---------
"""
Fungsi ini digunakan untuk proses tokenisasi yang dimana proses memecah kalimat menjadi kata-kata menjadi lebih berarti 
dan bermakna. Tokenisasi memisah setiap kata yang menyusun kalimat.
"""
def word_tokenize_wrapper(sentiment_text):
    tokens = word_tokenize(sentiment_text)
    
    #proses normalization menghilangkan slangword dari dict appos yang sebelumnya sudah dibuat
    reformed = [appos[word] if word in appos else word for word in tokens]
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in reformed]
    words = [word for word in stripped if word.isalpha()]
    return words

data['sentiment_text'] = data['sentiment_text'].apply(word_tokenize_wrapper)


print('Tokenizing Result : \n') 
print(data['sentiment_text'].head(20))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0     kenaikan harga dan kelangkaan minyak goreng te...
# 1     minyak goreng curah subsidi dari pemerintah be...
# 2     tidak perlu larang ekspor cpo daya bulog toko ...
# 3        minyak goreng tidak ada di pasar ciampea bogor
# 4     anggota komisi vii dpr ri mulyanto minta pemer...
# 5               minyak goreng belum terlihat di tabanan
# 6     aneh sih pas harga masih   liter nyarinya susa...
# 7     asli sih minyak goreng itu penting banget udah...
# 8     masih waras kah di mana keberpihakan negara kp...
# 9     brand baru negara kita adalah negara miskin su...
# 10    ini gak ada yang mau demo turunin harha minyak...
# 11    pemerintah emng   becus mengurus minyak goreng...
# 12    selamat datang di negara lawak dimana harga mi...
# 13    biaya minyak goreng turun mudah mudahan turun ...
# 14                            biaya minyak goreng turun
# 15    belum lagi daerah daerah pencil butuh minyak g...
# 16    anggota dpr ri biaya cpo dunia merosot biaya m...
# 17    harga minyak goreng di kota jambi hari ini jul...
# 18    turun terus harga minyak goreng jatuh terendah...
# 19            nilai rugi negara minyak goreng fantastis
# Name: sentiment_text, dtype: object
#
#
#
#
# Tokenizing Result :
#
# 0     [kenaikan, biaya, dan, kelangkaan, minyak, gor...
# 1     [minyak, goreng, curah, subsidi, dari, pemerin...
# 2     [tidak, perlu, larang, ekspor, cpo, daya, bulo...
# 3     [minyak, goreng, tidak, ada, di, pasar, ciampe...
# 4     [anggota, komisi, vii, dpr, ri, mulyanto, mint...
# 5        [minyak, goreng, belum, terlihat, di, tabanan]
# 6     [aneh, sih, pas, biaya, masih, liter, nyarinya...
# 7     [asli, sih, minyak, goreng, itu, penting, sang...
# 8     [masih, waras, kah, di, mana, keberpihakan, ne...
# 9     [brand, baru, negara, kita, adalah, negara, mi...
# 10    [ini, tidak, ada, yang, mau, demo, turunin, ha...
# 11    [pemerintah, memang, bisa, mengurus, minyak, g...
# 12    [selamat, datang, di, negara, lawak, dimana, b...
# 13    [biaya, minyak, goreng, turun, mudah, mudahan,...
# 14                       [biaya, minyak, goreng, turun]
# 15    [belum, lagi, daerah, daerah, pencil, butuh, m...
# 16    [anggota, dpr, ri, biaya, cpo, dunia, merosot,...
# 17    [biaya, minyak, goreng, di, kota, jambi, hari,...
# 18    [turun, terus, biaya, minyak, goreng, jatuh, t...
# 19     [nilai, rugi, negara, minyak, goreng, fantastis]
# Name: sentiment_text, dtype: object

# %%
def negative_handling(sentiment_text):
    negative_sentiment_text = []
    for i in range(len(sentiment_text)):
        word = sentiment_text[i]
        if sentiment_text[i-1] not in ['tidak','kurang','tak','tanpa','terlalu','bukan','belum']:
            negative_sentiment_text.append(word)
        else:
            word = "%s_%s" %(sentiment_text[i-1],word)
            negative_sentiment_text.append(word)
    return negative_sentiment_text

data['sentiment_text'] = data['sentiment_text'].apply(negative_handling)
print('Negation Result : \n') 
print(data['sentiment_text'].head(20))
print('\n\n\n')
# Out:
# Negation Result :
#
# 0     [kenaikan, biaya, dan, kelangkaan, minyak, gor...
# 1     [minyak, goreng, curah, subsidi, dari, pemerin...
# 2     [tidak, tidak_perlu, larang, ekspor, cpo, daya...
# 3     [minyak, goreng, tidak, tidak_ada, di, pasar, ...
# 4     [anggota, komisi, vii, dpr, ri, mulyanto, mint...
# 5     [minyak, goreng, belum, belum_terlihat, di, ta...
# 6     [aneh, sih, pas, biaya, masih, liter, nyarinya...
# 7     [asli, sih, minyak, goreng, itu, penting, sang...
# 8     [masih, waras, kah, di, mana, keberpihakan, ne...
# 9     [brand, baru, negara, kita, adalah, negara, mi...
# 10    [ini, tidak, tidak_ada, yang, mau, demo, turun...
# 11    [pemerintah, memang, bisa, mengurus, minyak, g...
# 12    [selamat, datang, di, negara, lawak, dimana, b...
# 13    [biaya, minyak, goreng, turun, mudah, mudahan,...
# 14                       [biaya, minyak, goreng, turun]
# 15    [belum, belum_lagi, daerah, daerah, pencil, bu...
# 16    [anggota, dpr, ri, biaya, cpo, dunia, merosot,...
# 17    [biaya, minyak, goreng, di, kota, jambi, hari,...
# 18    [turun, terus, biaya, minyak, goreng, jatuh, t...
# 19     [nilai, rugi, negara, minyak, goreng, fantastis]
# Name: sentiment_text, dtype: object

# %%
"""
Pada bagian ini merupakan proses untuk mengubah atau mengembalikan kata pada setiap kalimat ke bentuk dasar atau menghapus 
kata-kata imbuhan.Proses menemukan kata dasar (root word) dari kata berimbuhan (affixed word) dengan cara menghilangkan semua
imbuhan (affix) yang terdiri dari awalan (prefix), sisipan (infix), akhiran (suffix) dan kombinasi awalan dan akhiran (confix).
Algoritma yang digunakan algoritma Nazief dan Andriani.
"""

factory = StemmerFactory() #Variabel factory berisi class untuk proses stemming dari library stemming
stemmer = factory.create_stemmer() #Variabel stemmer digunakan untuk mengambil fungsi pembuatan stemming dari class StemmerFactory() 

#fungsi untuk proses stemming
def stemmed_wrapper(term):
  return stemmer.stem(term)

#variabel untuk menampung dictionary dari kata-kata term stemming
term_dict = {}

"""
Proses iterasi untuk pembuatan dict termnya, yang dimana akan dilakukan pengecekan kata kata hasil dari proses tokenisasi, 
Jadi setelah ditokenisasi, kemudian semua kata-kata tersebut akan ditampung di dalam term_dict yang dimana nantinya kata-kata 
tersebut akan melalui proses dari fungsi stemming. Jika kata tersebut bukan termasuk di variabel term_dict maka list kata di 
dictionary tersebut akan dikosongkan.
"""
for document in data['sentiment_text']:
  for term in document:
    if term not in term_dict:
      term_dict[term] = " "

print(len(term_dict))
print("------------------------------")

"""
proses iterasi untuk pengecekan setiap kata di dalam variabel term_dict, yang kemudian di dalam proses tersebut terjadinya
proses perubahan setiap kata yang akan dilakukan oleh fungsi stemmed_wrapper yang berisi proses stemming kata. Setelah itu,
akan ditampilkan hasil dari proses perubahan.
"""
for term in term_dict:
  term_dict[term] = stemmed_wrapper(term)
  print(term,":",term_dict[term])

#print(term_dict)
print("-----------------------------")

"""
Kemudian hasil perubahan stemmingnya dimasukkan ke dalam dataframe untuk diolah ke tahapan berikutnya
"""
def get_stemmed_term(document):
  return[term_dict[term] for term in document]

data['sentiment_text'] = data['sentiment_text'].apply(get_stemmed_term)
print(data['sentiment_text'])
# Out:
# 753
# ------------------------------
# kenaikan : naik
# biaya : biaya
# dan : dan
# kelangkaan : langka
# minyak : minyak
# goreng : goreng
# tentu : tentu
# membuat : buat
# masyarakat : masyarakat
# indonesia : indonesia
# kelimpungan : kelimpungan
# curah : curah
# subsidi : subsidi
# dari : dari
# pemerintah : perintah
# belum : belum
# belum_ada : belum ada
# di : di
# kota : kota
# malang : malang
# pedagang : dagang
# pembeli : beli
# mohon : mohon
# bersabar : sabar
# tidak : tidak
# tidak_perlu : tidak perlu
# larang : larang
# ekspor : ekspor
# cpo : cpo
# daya : daya
# bulog : bulog
# toko : toko
# jaring : jaring
# distribusi : distribusi
# produsen : produsen
# tidak_ada : tidak ada
# pasar : pasar
# ciampea : ciampea
# bogor : bogor
# anggota : anggota
# komisi : komisi
# vii : vii
# dpr : dpr
# ri : ri
# mulyanto : mulyanto
# minta : minta
# terus : terus
# menjaga : jaga
# momentum : momentum
# penurunan : turun
# sampai : sampai
# menuju : tuju
# het : het
# belum_terlihat : belum lihat
# tabanan : taban
# aneh : aneh
# sih : sih
# pas : pas
# masih : masih
# liter : liter
# nyarinya : nyarinya
# susah : susah
# sangat : sangat
# giliran : gilir
# normal : normal
# eh : eh
# rak : rak
# penuh : penuh
# asli : asli
# itu : itu
# penting : penting
# sudah : sudah
# mahal : mahal
# lagi : lagi
# tanpa : tanpa
# tanpa_minyak : tanpa minyak
# kita : kita
# tidak_bisa : tidak bisa
# berlemak : lemak
# riaa : riaa
# waras : waras
# kah : kah
# mana : mana
# keberpihakan : pihak
# negara : negara
# kepada : kepada
# rakyatnya : rakyat
# kalah : kalah
# oleh : oleh
# kartel : kartel
# brand : brand
# baru : baru
# adalah : adalah
# miskin : miskin
# pak : pak
# sombong : sombong
# banyak : banyak
# gaya : gaya
# rakyat : rakyat
# yang : yang
# tahu : tahu
# aslinya : asli
# ini : ini
# mau : mau
# demo : demo
# turunin : turunin
# harha : harha
# memang : memang
# bisa : bisa
# mengurus : urus
# cabut : cabut
# izin : izin
# produksi : produksi
# sawit : sawit
# kelar : kelar
# mata : mata
# sipit : sipit
# balik : balik
# kampung : kampung
# selamat : selamat
# datang : datang
# lawak : lawak
# dimana : mana
# penghasil : hasil
# cukup : cukup
# besar : besar
# turun : turun
# mudah : mudah
# mudahan : mudah
# tenang : tenang
# ayo : ayo
# disiplin : disiplin
# prokes : prokes
# yah : yah
# belum_lagi : belum lagi
# daerah : daerah
# pencil : pencil
# butuh : butuh
# dunia : dunia
# merosot : merosot
# jambi : jambi
# hari : hari
# juli : juli
# mulai : mulai
# rp : rp
# ribu : ribu
# per : per
# jatuh : jatuh
# terendah : rendah
# jadi : jadi
# nilai : nilai
# rugi : rugi
# fantastis : fantastis
# mendag : mendag
# klaim : klaim
# berhasil : hasil
# kendalikan : kendali
# hasil : hasil
# kendali : kendali
# zulkifli : zulkifli
# hasan : hasan
# kaji : kaji
# pencabutan : cabut
# aturan : atur
# dmo : dmo
# dpo : dpo
# minyakgoreng : minyakgoreng
# pertumbuhan : tumbuh
# ekonomi : ekonomi
# gagal : gagal
# meroket : roket
# lho : lho
# penegakan : tega
# hukum : hukum
# tidak_berkeadilan : tidak adil
# mendesak : desak
# segera : segera
# memasok : pasok
# lampung : lampung
# bengkulu : bengkulu
# hilirisasi : hilir
# dipertegas : tegas
# jokowi : jokowi
# akan : akan
# bangun : bangun
# pabrik : pabrik
# migor : migor
# kemasan : kemas
# sederhana : sederhana
# minyakita : minyakita
# belum_beredar : belum edar
# tradisional : tradisional
# bandar : bandar
# perintahkan : perintah
# menteri : menteri
# kukm : kukm
# merah : merah
# mengembangkan : kembang
# produk : produk
# red : red
# palm : palm
# oil : oil
# rpo : rpo
# atau : atau
# pengawas : awas
# persaingan : saing
# usaha : usaha
# kppu : kppu
# menaikkan : naik
# status : status
# kasus : kasus
# dugaan : duga
# diperkirakan : kira
# menimbulkan : timbul
# kerugian : rugi
# tidak_sedikit : tidak sedikit
# naik : naik
# tapi : tapi
# menurun : turun
# desak : desak
# pasok : pasok
# mengatur : atur
# jangan : jangan
# gorengan : goreng
# politik : politik
# saja : saja
# ada : ada
# curi : curi
# kesempatan : sempat
# ngurus : ngurus
# tidak_benar : tidak benar
# apalagi : apalagi
# lain : lain
# tidak_memperhatikan : tidak perhati
# perekonomian : ekonomi
# seenaknya : enak
# bulan : bulan
# bermasalah : masalah
# pks : pks
# menko : menko
# marves : marves
# cuma : cuma
# warga : warga
# tanjabtim : tanjabtim
# keluhkan : keluh
# stabilkan : stabil
# jurus : jurus
# selalu : selalu
# pertumbuh : tumbuh
# total : total
# karena : karena
# naiknya : naik
# legi : legi
# solo : solo
# mengalami : alami
# kemarin : kemarin
# usut : usut
# mafia : mafia
# cabai : cabai
# makin : makin
# pedas : pedas
# tambah : tambah
# licin : licin
# semenjak : semenjak
# apa : apa
# sekarang : sekarang
# lebih : lebih
# sering : sering
# gofood : gofood
# jarang : jarang
# masa : masa
# ibu : ibu
# takut : takut
# bapak : bapak
# bbm : bbm
# jaga : jaga
# kembang : kembang
# makan : makan
# segala : segala
# macam : macam
# ikut : ikut
# kemas : kemas
# belum_edar : belum edar
# tarif : tarif
# listrik : listrik
# mereka : mereka
# mingkem : mingkem
# berbulan : bulan
# tidak_rapi : tidak rapi
# jamin : jamin
# murah : murah
# tbs : tbs
# tani : tani
# serap : serap
# presiden : presiden
# kelola : kelola
# koperasi : koperasi
# cabe : cabe
# coba : coba
# kritik : kritik
# pakde : pakde
# juga : juga
# tinggi : tinggi
# uang : uang
# semakin : makin
# rendah : rendah
# untuk : untuk
# rupiah : rupiah
# ckckck : ckckck
# zulhas : zulhas
# kabar : kabar
# gembira : gembira
# widodo : widodo
# rencana : rencana
# alternatif : alternatif
# ganti : ganti
# bensin : bensin
# pajak : pajak
# sembako : sembako
# semua : semua
# hutang : hutang
# meningkat : tingkat
# pura : pura
# bahagia : bahagia
# kembangkan : kembang
# mie : mie
# kok : kok
# kadar : kadar
# cinta : cinta
# crushmu : crushmu
# tidak_naik : tidak naik
# harap : harap
# malah : malah
# buat : buat
# seminar : seminar
# rebusan : rebus
# waktu : waktu
# menderita : derita
# ganas : ganas
# mencekik : cekik
# selagi : selagi
# langsung : langsung
# ke : ke
# awan : awan
# turunya : turunya
# malas : malas
# an : an
# antrian : antri
# mengakibatkan : akibat
# orang : orang
# tewas : tewas
# korupsi : korupsi
# diberbagai : bagai
# menyatakan : nyata
# pasokan : pasok
# lancar : lancar
# terpencil : pencil
# sama : sama
# membutuhkan : butuh
# mengantre : antre
# dua : dua
# perliter : liter
# tolong : tolong
# turunkan : turun
# boros : boros
# loh : loh
# masalah : masalah
# belum_selesai : belum selesai
# usul : usul
# kemendag : kemendag
# kemenperin : kemenperin
# digabung : gabung
# yahhhh : yahhhh
# pantes : pantes
# jaman : jaman
# saiki : saiki
# isu : isu
# opo : opo
# wae : wae
# pokoke : pokoke
# kelapa : kelapa
# sawitnya : sawit
# duluan : duluan
# sebelum : belum
# lepas : lepas
# ni : ni
# pisang : pisang
# tepi : tepi
# jalan : jalan
# pun : pun
# sbb : sbb
# xleh : xleh
# pakai : pakai
# sesuai : sesuai
# eceran : ecer
# tertinggi : tinggi
# bahkan : bahkan
# bawahnya : bawah
# warning : warning
# tsunami : tsunami
# oversupply : oversupply
# jilid : jilid
# bijak : bijak
# antisipasi : antisipasi
# negeri : negeri
# sinergi : sinergi
# pusat : pusat
# buah : buah
# signifikan : signifikan
# stabilitas : stabilitas
# pangan : pangan
# khusus : khusus
# sengkarut : sengkarut
# sekian : sekian
# strategi : strategi
# zuklifli : zuklifli
# selesai : selesai
# hebat : hebat
# nambah : nambah
# utang : utang
# ugal : ugal
# gas : gas
# pada : pada
# proteksi : proteksi
# beneran : beneran
# dukung : dukung
# munafik : munafik
# tidak_tbs : tidak tbs
# tidak_cpo : tidak cpo
# anggap : anggap
# gugah : gugah
# perhati : perhati
# prihatin : prihatin
# luluh : luluh
# lantak : lantak
# moga : moga
# baca : baca
# buzzersss : buzzersss
# kampanye : kampanye
# merangkak : rangkak
# perkilonya : kilo
# antre : antre
# survei : survei
# lsi : lsi
# mayoritas : mayoritas
# percaya : percaya
# kejar : kejar
# batanghari : batanghari
# buka : buka
# posko : posko
# adu : adu
# langka : langka
# tanah : tanah
# pupuk : pupuk
# bilang : bilang
# sulit : sulit
# pejabat : jabat
# kalau : kalau
# tidak_malas : tidak malas
# mah : mah
# namanya : nama
# disaat : saat
# stok : stok
# melimpah : limpah
# semoga : moga
# vaksin : vaksin
# kesehatan : sehat
# jajanan : jajan
# sejak : sejak
# telor : telor
# tepung : tepung
# dkk : dkk
# gassss : gassss
# tidak_ini : tidak ini
# pokok : pokok
# terobos : terobos
# kerja : kerja
# nyata : nyata
# atur : atur
# dagang : dagang
# beli : beli
# sabar : sabar
# bawang : bawang
# minggu : minggu
# sedia : sedia
# aman : aman
# diskon : diskon
# meningkatkan : tingkat
# kolesterol : kolesterol
# beresiko : resiko
# penyakit : sakit
# jantung : jantung
# ungkap : ungkap
# kejari : kejar
# pengaduan : adu
# sebut : sebut
# telah : telah
# polisi : polisi
# sita : sita
# ton : ton
# banyumas : banyumas
# surabaya : surabaya
# ketua : ketua
# ikat : ikat
# ikappi : ikappi
# abdullah : abdullah
# mansuri : mansuri
# henti : henti
# jual : jual
# jagung : jagung
# kirim : kirim
# kardus : kardus
# jabat : jabat
# insfrastruktur : insfrastruktur
# bangkit : bangkit
# akademis : akademis
# skema : skema
# libat : libat
# tni : tni
# legislator : legislator
# terlalu : terlalu
# terlalu_lebih : terlalu lebih
# berharap : harap
# cepat : cepat
# ciduk : ciduk
# curang : curang
# timbang : timbang
# tanjung : tanjung
# priok : priok
# resor : resor
# cipta : cipta
# adil : adil
# tanpa_tebang : tanpa tebang
# pilih : pilih
# medan : medan
# belawan : belawan
# sumut : sumut
# sinyal : sinyal
# kena : kena
# tebus : tebus
# juni : juni
# duga : duga
# cc : cc
# pantau : pantau
# luhut : luhut
# aplikasi : aplikasi
# pedulilindungi : pedulilindungi
# kapan : kapan
# agen : agen
# tangkap : tangkap
# warakas : warakas
# raup : raup
# untung : untung
# capai : capai
# miliar : miliar
# ternyata : nyata
# pantas : pantas
# menengah : tengah
# bawah : bawah
# mengeluh : keluh
# mempersulit : sulit
# belum_lihat : belum lihat
# taban : taban
# kenapa : kenapa
# lambat : lambat
# menanggapi : tanggap
# tjakepp : tjakepp
# bantu : bantu
# informasi : informasi
# bandung : bandung
# raya : raya
# sekala : sekala
# nasional : nasional
# laku : laku
# ketat : ketat
# serba : serba
# tidak_bbm : tidak bbm
# ecer : ecer
# harapan : harap
# maju : maju
# selesaikan : selesai
# harus : harus
# percepat : cepat
# tidak_berpihak : tidak pihak
# syukur : syukur
# pungut : pungut
# ditiadakan : tiada
# sedikit : sedikit
# gratis : gratis
# tegur : tegur
# mungkin : mungkin
# periode : periode
# yo : yo
# tidak_tahu : tidak tahu
# tanya : tanya
# saya : saya
# ya : ya
# benar : benar
# minyaknya : minyak
# dipakai : pakai
# ngegoreng : ngegoreng
# tumben : tumben
# felangack : felangack
# felongock : felongock
# suaranya : suara
# dqn : dqn
# tidak_lempar : tidak lempar
# bagi : bagi
# direncanakan : rencana
# agar : agar
# pokoknya : pokok
# hidup : hidup
# mukidi : mukidi
# selanjutnya : lanjut
# dibuat : buat
# dulu : dulu
# lanjut : lanjut
# global : global
# saatnya : saat
# kreatif : kreatif
# sehat : sehat
# dalam : dalam
# mengolah : olah
# makanan : makan
# luncur : luncur
# program : program
# kemasyarakat : masyarakat
# dengan : dengan
# fokuslah : fokus
# urusin : urusin
# kebutuhan : butuh
# sibuk : sibuk
# urus : urus
# perpanjangan : panjang
# jabatan : jabat
# ketika : ketika
# diperas : peras
# tukang : tukang
# sumsumnya : sumsum
# maka : maka
# siapa : siapa
# membela : bela
# kolaborasi : kolaborasi
# malapetaka : malapetaka
# baik : baik
# daripada : daripada
# menjerit : jerit
# pula : pula
# tidak_mampu : tidak mampu
# ngeributin : ngeributin
# ninyak : ninyak
# memasak : masak
# kan : kan
# tidak_identik : tidak identik
# menggoreng : goreng
# demi : demi
# tol : tol
# sirkuit : sirkuit
# moto : moto
# gp : gp
# ikn : ikn
# laut : laut
# dapat : dapat
# naikin : naikin
# wiiiihh : wiiiihh
# terlihat : lihat
# jelas : jelas
# kaya : kaya
# alasannya : alas
# anda : anda
# oye : oye
# memiliki : milik
# ktp : ktp
# bahasanya : bahasa
# halus : halus
# keekonomian : ekonomi
# faktanya : fakta
# hancur : hancur
# umkm : umkm
# gorengnya : goreng
# nyari : nyari
# guampang : guampang
# beralih : alih
# bulus : bulus
# wasilah : wasilah
# rantai : rantai
# panjang : panjang
# terkena : kena
# dampak : dampak
# salam : salam
# naikkan : naik
# ironis : ironis
# terbesar : besar
# kacau : kacau
# yaa : yaa
# bahan : bahan
# hilang : hilang
# kemudian : kemudian
# dimanfaatkan : manfaat
# tiga : tiga
# menterinya : menteri
# pengusaha : usaha
# boneka : boneka
# batubara : batubara
# apaan : apa
# terkait : kait
# oh : oh
# tanggap : tanggap
# menimbun : timbun
# stock : stock
# menjijikkan : jijik
# sekali : sekali
# bukannya : bukan
# mengatasi : atas
# memanfaatkannya : manfaat
# memperpanjang : panjang
# melonjaknya : lonjak
# internasional : internasional
# berdampak : dampak
# termasuk : masuk
# mengintip : intip
# obrolan : obrol
# group : group
# menyelesaikan : selesai
# hilangnya : hilang
# tidak_membuat : tidak buat
# pecel : pecel
# lele : lele
# jualnya : jual
# memakai : pakai
# kali : kali
# lama : lama
# dengarlah : dengar
# jeritan : jerit
# bakul : bakul
# ampun : ampun
# tolongin : tolongin
# tempe : tempe
# gila : gila
# lembaga : lembaga
# riset : riset
# ginian : ginian
# jago : jago
# drpda : drpda
# kalian : kalian
# serta : serta
# padahal : padahal
# diurus : urus
# bareng : bareng
# pembantu : bantu
# rapi : rapi
# warteg : warteg
# barang : barang
# -----------------------------
# 0      [naik, biaya, dan, langka, minyak, goreng, ten...
# 1      [minyak, goreng, curah, subsidi, dari, perinta...
# 2      [tidak, tidak perlu, larang, ekspor, cpo, daya...
# 3      [minyak, goreng, tidak, tidak ada, di, pasar, ...
# 4      [anggota, komisi, vii, dpr, ri, mulyanto, mint...
#                              ...
# 995    [naik, biaya, dan, langka, minyak, goreng, kir...
# 996    [minyak, goreng, naik, terus, tapi, biaya, saw...
# 997    [warga, barang, sekarang, jadi, sering, beli, ...
# 998    [perintah, negara, akan, mulai, kembang, produ...
# 999    [warga, sekarang, jadi, sering, beli, warteg, ...
# Name: sentiment_text, Length: 1000, dtype: object

# %%
"""
Pada tahapan ini digunakan untuk proses menghilangkan kata-kata yang tidak mendeskripsikan pada studi kasus yang semestinya 
dihilangkan. Kata yang dihilangkan adalah kata yang ada dalam dictionary yang berisi daftar kata (stopword list). 
"""

# ----------------------- ambil stopword dari library NLTK -------------------------------
#Menggunakan file package Stopword berbahasa Indonesia yang sudah di install sebelumnya dalam library NLTK
list_stopwords = stopwords.words('indonesian')

# ---------------------------- menambahkan stopword secara manual  ------------------------------------
"""
Pada bagian ini digunakan untuk menambahkan beberapa kata Stopword secara manual jika dirasa masih 
ada beberapa kata yang ingin dihapus karena tidak relevan dengan studi kasus, dan kata tersebut tidak 
terdaftar pada file stopword bawaan dari library NLTK
"""
list_stopwords.extend(['yah','toh','lah','ud','lw','wkwk',
                       'jleb','ne','wkw','xyz','rt','dong','haha',
                       'oalah','ish','hih','ngnt','ew','ups','jilidiii',
                       'hm','cuk','hadeh','au','ah','via','ae','hem','mah',
                       'wkwkwk','yg', 'dg', 'rt', 'dgn', 'ny', 'd', 'klo', 
                       'kalo', 'amp', 'biar', 'krn', 'nya', 'nih', 'sih', 'tidak',
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh',
                       '&amp', 'os','hadeuh','neg','cukz','seh','euy','so',
                       'cmiw','pls','bhahaha','bhaha','blak','blakan','jreng',
                       'caur','penya','b','blablabla','seh','ni','owalah','dhobol','lho',
                       'adadeh'])

# ---------------------------------------------------------------------------------------

"""
Ubah data list menjadi bertipe data set agar tidak ada elemen  dengan nilai yang sama di dalam 1 file olahan stopwords
"""
list_stopwords = set(list_stopwords)

#Fungsi untuk hapus kata kata pada daftar list yang terdaftar dalam file package Stopwords sebelumnya
def stopwords_removal(words):
    return [word for word in words if not word in list_stopwords]

data['sentiment_text'] = data['sentiment_text'].apply(stopwords_removal) 

print(data['sentiment_text'].head(20))
# Out:
# 0     [biaya, langka, minyak, goreng, masyarakat, in...
# 1     [minyak, goreng, curah, subsidi, perintah, bel...
# 2     [tidak perlu, larang, ekspor, cpo, daya, bulog...
# 3     [minyak, goreng, tidak ada, pasar, ciampea, bo...
# 4     [anggota, komisi, vii, dpr, ri, mulyanto, peri...
# 5                  [minyak, goreng, belum lihat, taban]
# 6     [aneh, pas, biaya, liter, nyarinya, susah, gil...
# 7     [asli, minyak, goreng, mahal, nyarinya, susah,...
# 8     [waras, kah, negara, rakyat, kalah, kartel, mi...
# 9     [brand, negara, negara, miskin, susah, minyak,...
# 10    [tidak ada, demo, turunin, harha, minyak, goreng]
# 11    [perintah, urus, minyak, goreng, cabut, izin, ...
# 12    [selamat, negara, lawak, biaya, minyak, goreng...
# 13    [biaya, minyak, goreng, turun, mudah, mudah, t...
# 14                       [biaya, minyak, goreng, turun]
# 15    [belum lagi, daerah, daerah, pencil, butuh, mi...
# 16    [anggota, dpr, ri, biaya, cpo, dunia, merosot,...
# 17    [biaya, minyak, goreng, kota, jambi, juli, rp,...
# 18    [turun, biaya, minyak, goreng, jatuh, rendah, ...
# 19     [nilai, rugi, negara, minyak, goreng, fantastis]
# Name: sentiment_text, dtype: object

# %%
#Fungsi yang digunakan untuk menggabungkan setiap kata yang terpisah akibat proses tokenisasi sebelumnya
def join_text(sentiment_text):
    return ' '.join(sentiment_text)

data['sentiment_text'] = data['sentiment_text'].apply(join_text)
print(data['sentiment_text'].head(20))
# Out:
# 0     biaya langka minyak goreng masyarakat indonesi...
# 1     minyak goreng curah subsidi perintah belum ada...
# 2     tidak perlu larang ekspor cpo daya bulog toko ...
# 3           minyak goreng tidak ada pasar ciampea bogor
# 4     anggota komisi vii dpr ri mulyanto perintah ja...
# 5                       minyak goreng belum lihat taban
# 6     aneh pas biaya liter nyarinya susah gilir biay...
# 7     asli minyak goreng mahal nyarinya susah tanpa ...
# 8     waras kah negara rakyat kalah kartel minyak go...
# 9     brand negara negara miskin susah minyak goreng...
# 10           tidak ada demo turunin harha minyak goreng
# 11    perintah urus minyak goreng cabut izin produks...
# 12    selamat negara lawak biaya minyak goreng mahal...
# 13    biaya minyak goreng turun mudah mudah turun ma...
# 14                            biaya minyak goreng turun
# 15    belum lagi daerah daerah pencil butuh minyak g...
# 16    anggota dpr ri biaya cpo dunia merosot biaya m...
# 17    biaya minyak goreng kota jambi juli rp ribu liter
# 18      turun biaya minyak goreng jatuh rendah rp liter
# 19            nilai rugi negara minyak goreng fantastis
# Name: sentiment_text, dtype: object

# %%
#Jadikan hasil yang sudah di pre-processing sebelumnya menjadi bentuk CSV untuk proses pengolahan berikutnya
df=pd.DataFrame(data['sentiment_text'])
df.to_csv('D:/data2023/databersih.csv', header=None, index=False)

# %% [markdown]
# # Remove Duplicate Data

# %%
#Import file setelah hasil pre-processing yang ingin dilakukan proses penghapusan data yang ganda
header_list = ["text"]
minyak_pre = pd.read_csv('D:/data2023/databersih.csv', names=header_list)
minyak_pre
# Out:
#                                                   text
# 0    biaya langka minyak goreng masyarakat indonesi...
# 1    minyak goreng curah subsidi perintah belum ada...
# 2    tidak perlu larang ekspor cpo daya bulog toko ...
# 3          minyak goreng tidak ada pasar ciampea bogor
# 4    anggota komisi vii dpr ri mulyanto perintah ja...
# ..                                                 ...
# 995  biaya langka minyak goreng timbul rugi ekonomi...
# 996                    minyak goreng biaya sawit turun
# 997             warga barang beli warteg minyak goreng
# 998  perintah negara kembang produk red palm oil rp...
# 999                    warga beli warteg minyak goreng
#
# [1000 rows x 1 columns]

# %%
#Untuk cek berapa banyaknya komentar yang duplikat atau ganda dalam 1 dataset yang diolah
print(minyak_pre[minyak_pre.duplicated(subset=['text'])])
# Out:
#                                                   text
# 21      mendag klaim hasil kendali biaya minyak goreng
# 33   anggota komisi vii dpr ri mulyanto desak perin...
# 41     warga tanjabtim keluh biaya minyak goreng mahal
# 54   minyak goreng kemas sederhana minyakita belum ...
# 56   jokowi perintah menteri kukm produksi minyak g...
# ..                                                 ...
# 993  perintah kembang produk red palm oil rpo minya...
# 994  komisi awas saing usaha kppu status duga karte...
# 995  biaya langka minyak goreng timbul rugi ekonomi...
# 996                    minyak goreng biaya sawit turun
# 999                    warga beli warteg minyak goreng
#
# [818 rows x 1 columns]

# %%
#Untuk cek berapa banyaknya komentar yang tidak duplikat atau ganda dalam 1 dataset yang diolah
print(minyak_pre[~minyak_pre.duplicated(subset=['text'])])
# Out:
#                                                   text
# 0    biaya langka minyak goreng masyarakat indonesi...
# 1    minyak goreng curah subsidi perintah belum ada...
# 2    tidak perlu larang ekspor cpo daya bulog toko ...
# 3          minyak goreng tidak ada pasar ciampea bogor
# 4    anggota komisi vii dpr ri mulyanto perintah ja...
# ..                                                 ...
# 990  ngurus minyak goreng bahan pokok tidak bisa ur...
# 991                biaya minyak goreng tidak rapi rapi
# 992                    warga beli warteg minyak goreng
# 997             warga barang beli warteg minyak goreng
# 998  perintah negara kembang produk red palm oil rp...
#
# [182 rows x 1 columns]

# %%
"""
Seleksi setiap baris data berdasarkan kolom text yang tidak duplikat atau ganda, tanda (~) merupakan negasi yang artinya
kebalikan dari data duplikat agar menghapus data yang ganda dan menampilkan komentar yang unik dan tidak duplikat

Lalu kemudian, simpan data yang tidak duplikat ke dalam file CSV yang berbeda
"""

minyak_pre[~minyak_pre.duplicated(subset=['text'])].to_csv('D:/data2023/databersihss.csv', header=None, index=False)

# %%
minyak_pre[~minyak_pre.duplicated(subset=['text'])].to_csv('D:/data2023/databersihs2.csv', header=None, index=False)
